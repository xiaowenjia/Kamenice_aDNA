# %% [markdown]
# schmutzi

# %%
# !qsub script1.sh

# %%
# !qsub TEMPLATE_retrive_schmutzi_200714.sh

# %% [markdown]
# Haplogrep

# %%
# !java -jar /mnt/archgen/users/yu/s.software/haplogrep-2.1.25.jar --format fasta --in /mnt/archgen/users/xiaowen/Kamenice/1024/schmutzi/0226_mt/KNC.mt.020226.MTconsensus.schmutzi.nolen.fasta --out /mnt/archgen/users/xiaowen/Kamenice/1024/schmutzi/0226_mt/KNC.mt.020226.MTconsensus_Haplogroups.txt --extend-report

# %%
# !java -jar /mnt/archgen/users/yu/s.software/haplogrep-2.1.25.jar --format fasta --in /mnt/archgen/users/xiaowen/Kamenice/1024/schmutzi/191024/KNC.RM.191024.MTcont.schmutzi.nolen.fasta --out /mnt/archgen/users/xiaowen/Kamenice/1024/schmutzi/191024/KNC.RM.191024.MTcont_Haplogroups.txt --extend-report

# %%
# !./collect_results.sh
